# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

def mean_squared_error(y, yp):
    size = len(y)
    sum = 0
    for index in range(size):
        sum = sum + ((y[index] + yp[index]) ** 2)
    result = sum / size
    return result

# %%
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 122122.096
# The Mean absolute error is 12.917

# %% [markdown]
# 1. 數據列出13個常見的心臟衰竭，其中包含性別，年齡和是否得過糖尿病等，可以用來分析什麼族群是屬於高危險族群已提早觀察
# 2. BMC Medical Informatics and Decision Making
# 3. 已整理結構化的row data
# 4. 根據13格提供最長因素，並排列組合，找尋最高可能心臟衰竭的原因，由高到低

# %% [markdown]
# 1. 希望透過數據，提高載客率，以提高營收
# 2. 資料由車隊提供，每次載客地點，到達地點，性別，預估年齡(每五到十歲為一個區間), 客群（學生，上班族）
# 3. 已整理結構化的資料
# 4. 以載客地點，性別年齡客群，去分析哪些地點，在什麼時間段，是否會比較高峰載客群。
#    同時根據到達地分析，是否較偏僻，難已載到客人，以降低，並根據結果分配更多的車輛在附近~ 驗證方法觀察 營收與載客量是否變高
